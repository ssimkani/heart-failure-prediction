# %% [markdown]
# **Visualizations**

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 4
#       2 import numpy as np
#       3 import pandas as pd
# ----> 4 import seaborn as sns
#
# File ~/repos/heart-failure-prediction/env/lib/python3.13/site-packages/seaborn/__init__.py:5
#       3 from .utils import *  # noqa: F401,F403
#       4 from .palettes import *  # noqa: F401,F403
# ----> 5 from .relational import *  # noqa: F401,F403
#       6 from .regression import *  # noqa: F401,F403
#       7 from .categorical import *  # noqa: F401,F403
#
# File ~/repos/heart-failure-prediction/env/lib/python3.13/site-packages/seaborn/relational.py:21
#      13 from .utils import (
#      14     adjust_legend_subtitles,
#      15     _default_color,
#    (...)     18     _scatter_legend_artist,
#      19 )
#      20 from ._compat import groupby_apply_include_groups
# ...

# %%
# Load dataset
df = pd.read_csv("../../data/processed/heart_processed.csv")

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 894   45   M            TA        110          264          0     Normal
# 895   68   M           ASY        144          193          1     Normal
# 896   57   M           ASY        130          131          0     Normal
# 897   57   F           ATA        130          236          0        LVH
# 898   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
# Association between Sex and Heart Disease
plt.figure(figsize=(10, 6))
plt.title("Association between Sex and Heart Disease", fontsize=20)
sns.countplot(x="Sex", hue="HeartDisease", data=df)
# Out:
# <Axes: title={'center': 'Association between Sex and Heart Disease'}, xlabel='Sex', ylabel='count'>

# %%
# Association between Age and Heart Disease
plt.figure(figsize=(10, 6))
plt.title("Association between Age (Years) and Heart Disease", fontsize=20)
sns.boxplot(x="HeartDisease", y="Age", data=df)
# Out:
# <Axes: title={'center': 'Association between Age (Years) and Heart Disease'}, xlabel='HeartDisease', ylabel='Age'>

# %%
# Association between Sex and Heart Disease
plt.figure(figsize=(10, 6))
plt.title("Association between Chest Pain Type and Heart Disease", fontsize=20)
sns.countplot(x="HeartDisease", hue="ChestPainType", data=df)
# Out:
# <Axes: title={'center': 'Association between Chest Pain Type and Heart Disease'}, xlabel='HeartDisease', ylabel='count'>

# %%
# Association between Resting Blood Pressure and Heart Disease
plt.figure(figsize=(10, 6))
plt.title("Association between Resting Blood Pressure (mmHG) and Heart Disease", fontsize=20)
sns.boxplot(x="HeartDisease", y="RestingBP", data=df)
# Out:
# <Axes: title={'center': 'Association between Resting Blood Pressure (mmHG) and Heart Disease'}, xlabel='HeartDisease', ylabel='RestingBP'>

# %%
# Association between Cholesterol and Heart Disease
plt.figure(figsize=(10, 6))
plt.title("Association between Cholesterol (mg/dl) and Heart Disease", fontsize=20)
sns.boxplot(x="HeartDisease", y="Cholesterol", data=df)
# Out:
# <Axes: title={'center': 'Association between Cholesterol (mm/dl) and Heart Disease'}, xlabel='HeartDisease', ylabel='Cholesterol'>

# %%
# Association between Fasting Blood Sugar and Heart Disease
plt.figure(figsize=(10, 6))
plt.title("Association between Fasting Blood Sugar and Heart Disease", fontsize=20)
plt.xlabel("Fasting Blood Sugar   1: FastingBS > 120 mg/dl;   0: Otherwise", fontsize=15)
sns.countplot(x="FastingBS", hue="HeartDisease", data=df)
# Out:
# <Axes: title={'center': 'Association between Fasting Blood Sugar and Heart Disease'}, xlabel='Fasting Blood Sugar   1: FastingBS > 120 mg/dl;   0: Otherwise', ylabel='count'>

# %%
# Association between resting electrocardiogram results and Heart Disease
plt.figure(figsize=(10, 6))
plt.title("Association between Resting Electrocardiogram Results and Heart Disease", fontsize=20)
sns.countplot(x="HeartDisease", hue="RestingECG", data=df)
# Out:
# <Axes: title={'center': 'Association between Resting Electrocardiogram Results and Heart Disease'}, xlabel='HeartDisease', ylabel='count'>

# %%
# Association between Max Heart Rate and Heart Disease
plt.figure(figsize=(10, 6))
plt.title("Association between Max Heart Rate (BPM) and Heart Disease", fontsize=20)
sns.boxplot(x="HeartDisease", y="MaxHR", data=df)
# Out:
# <Axes: title={'center': 'Association between Max Heart Rate (BPM) and Heart Disease'}, xlabel='HeartDisease', ylabel='MaxHR'>

# %%
# Association between Exercise Angina and Heart Disease
plt.figure(figsize=(10, 6))
plt.title("Association between Exercise Angina and Heart Disease", fontsize=20)
sns.countplot(x="HeartDisease", hue="ExerciseAngina", data=df)
# Out:
# <Axes: title={'center': 'Association between Exercise Angina and Heart Disease'}, xlabel='HeartDisease', ylabel='count'>

# %%
# Association between Oldpeak and Heart Disease
plt.figure(figsize=(10, 6))
plt.title("Association between Oldpeak and Heart Disease", fontsize=20)
plt.ylabel("Oldpeak = ST depression induced by exercise relative to rest", fontsize=10)
sns.boxplot(x="HeartDisease", y="Oldpeak", data=df)
# Out:
# <Axes: title={'center': 'Association between Oldpeak and Heart Disease'}, xlabel='HeartDisease', ylabel='Oldpeak = ST depression induced by exercise relative to rest'>

# %%
# Association between ST Slope and Heart Disease
plt.figure(figsize=(10, 6))
plt.title("Association between ST Slope and Heart Disease", fontsize=20)
sns.countplot(x="HeartDisease", hue="ST_Slope", data=df)
# Out:
# <Axes: title={'center': 'Association between ST Slope and Heart Disease'}, xlabel='HeartDisease', ylabel='count'>
